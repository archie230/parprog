# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import os

# %%
# !make
# Out:
# make: Nothing to be done for 'all'.

# %%
odd_even_time = []
pool_size = int(1e5)
pool = np.random.choice(np.arange(1e6), pool_size)
np.savetxt('input.txt', pool, fmt='%i')

for i in tqdm(np.arange(1, 9)):
    start = time.time()
    # !mpirun -n $i sort_mpi input.txt
    end = time.time()
    odd_even_time.append(end-start)
# Out:
# ...
# The result is:
# ...

# %%
plt.figure(figsize=(10, 8))
plt.plot(odd_even_time)
plt.ylabel('time')
plt.xlabel('workers num')
plt.show()
